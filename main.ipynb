# %%
from backtester import QuantEngine

TICKER = "ASELS.IS"   # "THYAO.IS" GARAN.IS or  ASELS.IS)
START_DATE = "2015-01-01"
END_DATE = "2025-01-01"
INITIAL_CAPITAL = 10000

if __name__ == "__main__":
    bot = QuantEngine(TICKER, START_DATE, END_DATE, INITIAL_CAPITAL)
    bot.fetch_data()
    bot.run_pipeline()
    bot.show_results()
# Out:
# ...
# Calculating indicators...
#
# ...
#  BACKTEST RESULTS: ASELS.IS
# ...
# Final Equity    : 13949.75 TRY
# CAGR            : %48.83
# Sharpe Ratio    : 1.15
# Max Drawdown    : %-63.18
# Profit Factor   : 1.24
# Win Rate        : %48.21
# /Users/elifakbas/Desktop/Finance/Indıcator Backtest Project/backtester.py:80: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   def calculate_cagr(data):
